# %%
import pandas as pd
import os
import glob
from collections import defaultdict
import warnings
import requests
warnings.filterwarnings('ignore')

def load_game_dates():
    """Load game dates data from GitHub"""
    url = 'https://raw.githubusercontent.com/gabriel1200/shot_data/refs/heads/master/game_dates.csv'
    try:
        game_dates_df = pd.read_csv(url)
        print(f"Loaded game dates data: {len(game_dates_df)} rows")
        
        # Convert GAME_ID and TEAM_ID to strings for consistent matching
        game_dates_df['GAME_ID'] = game_dates_df['GAME_ID'].astype(str)
        game_dates_df['TEAM_ID'] = game_dates_df['TEAM_ID'].astype(str)
        
        return game_dates_df
    except Exception as e:
        print(f"Error loading game dates data: {e}")
        return None

def get_team_acronym_from_id(team_id):
    """Convert team ID to team acronym using the provided dictionary"""
    team_dict = {
        '1610612760': 'OKC', '1610612749': 'MIL', '1610612758': 'SAC', '1610612747': 'LAL',
        '1610612738': 'BOS', '1610612743': 'DEN', '1610612750': 'MIN', '1610612752': 'NYK',
        '1610612756': 'PHX', '1610612753': 'ORL', '1610612766': 'CHA', '1610612739': 'CLE',
        '1610612746': 'LAC', '1610612737': 'ATL', '1610612748': 'MIA', '1610612742': 'DAL',
        '1610612765': 'DET', '1610612763': 'MEM', '1610612761': 'TOR', '1610612741': 'CHI',
        '1610612754': 'IND', '1610612759': 'SAS', '1610612745': 'HOU', '1610612751': 'BKN',
        '1610612764': 'WAS', '1610612744': 'GSW', '1610612755': 'PHI', '1610612762': 'UTA',
        '1610612757': 'POR', '1610612740': 'NOP'
    }
    
    team_id_str = str(int(team_id)) if pd.notna(team_id) else None
    return team_dict.get(team_id_str, f'UNKNOWN_{team_id_str}')

def determine_game_type(game_id):
    """Determine if game is regular season (rs) or playoffs (ps) based on game ID"""
    game_id_str = str(game_id)
    if game_id_str.startswith('4'):
        return 'ps'  # Playoffs
    elif game_id_str.startswith('2'):
        return 'rs'  # Regular season
    else:
        return 'unknown'

def get_teams_in_game(df):
    """Get the two teams that participated in the game"""
    teams = df['teamId'].dropna().unique()
    # Filter out any invalid team IDs and convert to strings
    valid_teams = []
    for team in teams:
        try:
            team_str = str(int(team))
            valid_teams.append(team_str)
        except (ValueError, TypeError):
            continue
    
    return valid_teams

def merge_game_dates_data(game_df, game_dates_df):
    """Merge game dates data with the game DataFrame"""
    if game_dates_df is None:
        print("Warning: No game dates data available for merging")
        return game_df
    
    # Convert game_df columns to strings for consistent matching
    game_df['game_id_str'] = game_df['game_id'].astype(str)
    game_df['teamId_str'] = game_df['teamId'].astype(int).astype(str)
    
    # Create merge key
    game_df['merge_key'] = game_df['game_id_str'] + '_' + game_df['teamId_str']
    game_dates_df['merge_key'] = game_dates_df['GAME_ID'] + '_' + game_dates_df['TEAM_ID']
    
    # Merge the data
    merged_df = game_df.merge(
        game_dates_df[['merge_key', 'date', 'playoffs', 'team', 'opp_team']], 
        on='merge_key', 
        how='left'
    )
    
    # Clean up temporary columns
    merged_df = merged_df.drop(['merge_key', 'game_id_str', 'teamId_str'], axis=1)
    
    # Report merge statistics
    matched_rows = merged_df['date'].notna().sum()
    total_rows = len(merged_df)
    print(f"    Merged game dates: {matched_rows}/{total_rows} rows matched")
    
    return merged_df

def collect_and_organize_data():
    """Main function to collect and organize scraped PBP data"""
    
    # Load game dates data first
    game_dates_df = load_game_dates()
    
    # Create output directories
    os.makedirs('organized_data', exist_ok=True)
    os.makedirs('organized_data/regular_season', exist_ok=True)
    os.makedirs('organized_data/playoffs', exist_ok=True)
    
    # Get all CSV files from pbp_data directory
    pbp_files = glob.glob('pbp_data/*.csv')
    
    if not pbp_files:
        print("No PBP data files found in pbp_data directory!")
        return
    
    print(f"Found {len(pbp_files)} PBP data files")
    
    # Dictionary to store complete game data by team, year, and game type
    # Structure: team_games[team_acronym][year][game_type] = [list of complete game DataFrames]
    team_games = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
    
    # Process each file (each file represents one complete game)
    processed_files = 0
    skipped_files = 0
    
    for file_path in pbp_files:
        try:
            # Extract year from filename (format: YYYY_GAMEID.csv)
            filename = os.path.basename(file_path)
            if '_' not in filename:
                print(f"Skipping file with unexpected format: {filename}")
                skipped_files += 1
                continue
            
            year = filename.split('_')[0]
            
            # Read the complete game CSV file
            game_df = pd.read_csv(file_path)
            
            if game_df.empty:
                print(f"Skipping empty file: {filename}")
                skipped_files += 1
                continue
            
            # Check if required columns exist
            required_columns = ['teamId', 'game_id']
            missing_columns = [col for col in required_columns if col not in game_df.columns]
            if missing_columns:
                print(f"Skipping file {filename} - missing columns: {missing_columns}")
                skipped_files += 1
                continue
            
            # Merge with game dates data
            game_df = merge_game_dates_data(game_df, game_dates_df)
            
            # Get the teams that participated in this game
            teams_in_game = get_teams_in_game(game_df)
            
            if len(teams_in_game) == 0:
                print(f"No valid team IDs found in {filename}")
                skipped_files += 1
                continue
            
            # Determine game type from game_id
            game_ids = game_df['game_id'].dropna().unique()
            if len(game_ids) == 0:
                print(f"No valid game IDs found in {filename}")
                skipped_files += 1
                continue
            
            # Use first game_id to determine game type (should be consistent within file)
            game_type = determine_game_type(game_ids[0])
            
            if game_type == 'unknown':
                print(f"Unknown game type for {filename} (game_id: {game_ids[0]})")
                skipped_files += 1
                continue
            
            # Add this complete game to each participating team's collection
            for team_id in teams_in_game:
                team_acronym = get_team_acronym_from_id(team_id)
                
                # Add the complete game DataFrame (includes both teams' actions)
                team_games[team_acronym][year][game_type].append(game_df.copy())
            
            processed_files += 1
            
            if processed_files % 100 == 0:
                print(f"Processed {processed_files} files...")
                
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
            skipped_files += 1
            continue
    
    print(f"\nProcessed {processed_files} files, skipped {skipped_files} files")
    
    # Combine and save data for each team/year/game_type combination
    total_files_created = 0
    
    for team_acronym in team_games:
        for year in team_games[team_acronym]:
            for game_type in team_games[team_acronym][year]:
                # Combine all complete games for this team/year/game_type
                combined_games_df = pd.concat(team_games[team_acronym][year][game_type], ignore_index=True)
                
                # Sort by game_id and actionNumber for consistent ordering
                combined_games_df = combined_games_df.sort_values(['date','period','actionNumber'])
                
                # Create filename
                game_type_folder = 'regular_season' if game_type == 'rs' else 'playoffs'
                filename = f"organized_data/{game_type_folder}/{team_acronym}_{year}_{game_type}.csv"
                filename2 = f"organized_data/{game_type_folder}/{team_acronym}_{year}_{game_type}.parquet"
                
                # Save to CSV
                combined_games_df.to_csv(filename, index=False)
                combined_games_df.to_parquet(filename2,index=False)
                # Count unique games for this team
                unique_games = combined_games_df['game_id'].nunique()
                
                # Count games with date information
                games_with_dates = combined_games_df.groupby('game_id')['date'].first().notna().sum()
                
                total_files_created += 1
                print(f"Created: {filename} ({len(combined_games_df)} rows, {unique_games} games, {games_with_dates} games with dates)")
    
    print(f"\nData organization complete!")
    print(f"Total files created: {total_files_created}")
    
    # Print summary statistics
    print("\nSummary by team:")
    for team_acronym in sorted(team_games.keys()):
        years = sorted(team_games[team_acronym].keys())
        rs_years = []
        ps_years = []
        
        for year in years:
            if 'rs' in team_games[team_acronym][year]:
                rs_games = len(team_games[team_acronym][year]['rs'])
                rs_years.append(f"{year}({rs_games})")
            if 'ps' in team_games[team_acronym][year]:
                ps_games = len(team_games[team_acronym][year]['ps'])
                ps_years.append(f"{year}({ps_games})")
        
        print(f"  {team_acronym}: RS: {rs_years}, PS: {ps_years}")

def verify_organized_data():
    """Verify the organized data files"""
    print("\nVerifying organized data files...")
    
    rs_files = glob.glob('organized_data/regular_season/*.csv')
    ps_files = glob.glob('organized_data/playoffs/*.csv')
    
    print(f"Regular season files: {len(rs_files)}")
    print(f"Playoff files: {len(ps_files)}")
    
    # Sample a few files to verify structure
    sample_files = (rs_files + ps_files)[:5]
    
    for file_path in sample_files:
        try:
            df = pd.read_csv(file_path)
            filename = os.path.basename(file_path)
            
            # Get team info
            teams_in_data = df['teamId'].dropna().unique()
            team_acronyms = [get_team_acronym_from_id(tid) for tid in teams_in_data]
            unique_games = df['game_id'].nunique()
            
            # Check for new columns
            has_date = 'date' in df.columns
            has_playoffs = 'playoffs' in df.columns
            has_team = 'team' in df.columns
            has_opp_team = 'opp_team' in df.columns
            
            # Count rows with date information
            rows_with_dates = df['date'].notna().sum() if has_date else 0
            
            print(f"  {filename}: {len(df)} rows, {unique_games} games, teams: {team_acronyms}")
            print(f"    New columns - date: {has_date}({rows_with_dates}), playoffs: {has_playoffs}, team: {has_team}, opp_team: {has_opp_team}")
            
            # Check game type consistency
            game_ids = df['game_id'].unique()
            game_types = [determine_game_type(gid) for gid in game_ids]
            unique_game_types = set(game_types)
            
            if len(unique_game_types) > 1:
                print(f"    WARNING: Mixed game types found: {unique_game_types}")
            
            # Verify both teams' actions are present
            if len(teams_in_data) < 2:
                print(f"    WARNING: Expected 2 teams, found {len(teams_in_data)}")
            
            # Show sample of new data
            if has_date and rows_with_dates > 0:
                sample_row = df[df['date'].notna()].iloc[0]
                print(f"    Sample: date={sample_row.get('date', 'N/A')}, team={sample_row.get('team', 'N/A')}, opp_team={sample_row.get('opp_team', 'N/A')}")
            
        except Exception as e:
            print(f"    ERROR reading {file_path}: {e}")

if __name__ == "__main__":
    print("Starting NBA PBP data collection and organization...")
    collect_and_organize_data()
    verify_organized_data()
    print("\nProcess complete!")
# Out:
# Starting NBA PBP data collection and organization...
# Loaded game dates data: 73291 rows
# Found 6422 PBP data files
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 579/579 rows matched
#     Merged game dates: 471/471 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 571/571 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 491/491 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 604/604 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 486/486 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 494/494 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 454/454 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 545/545 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 476/476 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 461/461 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 484/484 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 482/482 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 582/582 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 592/592 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 482/482 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 499/499 rows matched
#     Merged game dates: 575/575 rows matched
#     Merged game dates: 464/464 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 566/566 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 490/490 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 599/599 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 457/457 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 604/604 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 526/526 rows matched
# Processed 100 files...
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 607/607 rows matched
#     Merged game dates: 622/622 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 470/470 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 607/607 rows matched
#     Merged game dates: 474/474 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 562/562 rows matched
#     Merged game dates: 557/557 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 674/674 rows matched
#     Merged game dates: 589/589 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 586/586 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 647/647 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 492/492 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 475/475 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 582/582 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 494/494 rows matched
#     Merged game dates: 476/476 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 577/577 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 545/545 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 588/588 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 662/662 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 481/481 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 557/557 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 491/491 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 595/595 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 572/572 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 492/492 rows matched
# Processed 200 files...
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 476/476 rows matched
#     Merged game dates: 566/566 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 588/588 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 600/600 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 484/484 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 493/493 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 496/496 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 617/617 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 584/584 rows matched
#     Merged game dates: 494/494 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 595/595 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 567/567 rows matched
#     Merged game dates: 572/572 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 491/491 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 482/482 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 633/633 rows matched
#     Merged game dates: 581/581 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 611/611 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 579/579 rows matched
#     Merged game dates: 490/490 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 570/570 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 602/602 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 586/586 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 477/477 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 588/588 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 545/545 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 532/532 rows matched
# Processed 300 files...
#     Merged game dates: 494/494 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 493/493 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 507/507 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 566/566 rows matched
#     Merged game dates: 467/467 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 469/469 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 572/572 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 463/463 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 582/582 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 455/455 rows matched
#     Merged game dates: 575/575 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 489/489 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 545/545 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 481/481 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 570/570 rows matched
#     Merged game dates: 548/548 rows matched
#     Merged game dates: 500/500 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 545/545 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 612/612 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 463/463 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 570/570 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 584/584 rows matched
#     Merged game dates: 469/469 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 500/500 rows matched
#     Merged game dates: 489/489 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 467/467 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 584/584 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 558/558 rows matched
# Processed 400 files...
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 501/501 rows matched
#     Merged game dates: 571/571 rows matched
#     Merged game dates: 482/482 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 513/513 rows matched
#     Merged game dates: 492/492 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 513/513 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 548/548 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 566/566 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 467/467 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 592/592 rows matched
#     Merged game dates: 602/602 rows matched
#     Merged game dates: 614/614 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 493/493 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 469/469 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 584/584 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 589/589 rows matched
#     Merged game dates: 499/499 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 466/466 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 575/575 rows matched
#     Merged game dates: 598/598 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 454/454 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 488/488 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 595/595 rows matched
#     Merged game dates: 584/584 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 622/622 rows matched
#     Merged game dates: 602/602 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 599/599 rows matched
#     Merged game dates: 482/482 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 485/485 rows matched
#     Merged game dates: 511/511 rows matched
# Processed 500 files...
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 456/456 rows matched
#     Merged game dates: 513/513 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 605/605 rows matched
#     Merged game dates: 589/589 rows matched
#     Merged game dates: 566/566 rows matched
#     Merged game dates: 602/602 rows matched
#     Merged game dates: 604/604 rows matched
#     Merged game dates: 501/501 rows matched
#     Merged game dates: 456/456 rows matched
#     Merged game dates: 571/571 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 633/633 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 585/585 rows matched
#     Merged game dates: 591/591 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 641/641 rows matched
#     Merged game dates: 589/589 rows matched
#     Merged game dates: 488/488 rows matched
#     Merged game dates: 476/476 rows matched
#     Merged game dates: 490/490 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 500/500 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 461/461 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 548/548 rows matched
#     Merged game dates: 480/480 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 577/577 rows matched
#     Merged game dates: 467/467 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 562/562 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 606/606 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 460/460 rows matched
#     Merged game dates: 489/489 rows matched
#     Merged game dates: 591/591 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 494/494 rows matched
#     Merged game dates: 548/548 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 489/489 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 481/481 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 586/586 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 587/587 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 586/586 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 571/571 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 523/523 rows matched
# Processed 600 files...
#     Merged game dates: 599/599 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 474/474 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 585/585 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 690/690 rows matched
#     Merged game dates: 679/679 rows matched
#     Merged game dates: 488/488 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 493/493 rows matched
#     Merged game dates: 562/562 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 612/612 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 452/452 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 491/491 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 485/485 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 581/581 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 619/619 rows matched
#     Merged game dates: 576/576 rows matched
#     Merged game dates: 513/513 rows matched
#     Merged game dates: 557/557 rows matched
#     Merged game dates: 507/507 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 662/662 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 494/494 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 507/507 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 650/650 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 637/637 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 489/489 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 635/635 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 599/599 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 481/481 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 575/575 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 570/570 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 588/588 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 495/495 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 576/576 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 479/479 rows matched
#     Merged game dates: 530/530 rows matched
# Processed 700 files...
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 487/487 rows matched
#     Merged game dates: 513/513 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 571/571 rows matched
#     Merged game dates: 610/610 rows matched
#     Merged game dates: 599/599 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 603/603 rows matched
#     Merged game dates: 500/500 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 659/659 rows matched
#     Merged game dates: 461/461 rows matched
#     Merged game dates: 590/590 rows matched
#     Merged game dates: 630/630 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 579/579 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 609/609 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 478/478 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 491/491 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 489/489 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 503/503 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 500/500 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 619/619 rows matched
#     Merged game dates: 567/567 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 608/608 rows matched
#     Merged game dates: 487/487 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 567/567 rows matched
#     Merged game dates: 605/605 rows matched
#     Merged game dates: 625/625 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 548/548 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 562/562 rows matched
#     Merged game dates: 684/684 rows matched
#     Merged game dates: 562/562 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 462/462 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 526/526 rows matched
#     Merged game dates: 462/462 rows matched
#     Merged game dates: 565/565 rows matched
#     Merged game dates: 507/507 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 590/590 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 600/600 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 455/455 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 618/618 rows matched
#     Merged game dates: 530/530 rows matched
# Processed 800 files...
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 542/542 rows matched
#     Merged game dates: 476/476 rows matched
#     Merged game dates: 598/598 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 649/649 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 574/574 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 557/557 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 490/490 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 501/501 rows matched
#     Merged game dates: 487/487 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 690/690 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 606/606 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 501/501 rows matched
#     Merged game dates: 493/493 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 588/588 rows matched
#     Merged game dates: 464/464 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 570/570 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 488/488 rows matched
#     Merged game dates: 618/618 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 582/582 rows matched
#     Merged game dates: 487/487 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 481/481 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 546/546 rows matched
#     Merged game dates: 569/569 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 670/670 rows matched
#     Merged game dates: 576/576 rows matched
#     Merged game dates: 594/594 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 465/465 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 500/500 rows matched
#     Merged game dates: 537/537 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 603/603 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 583/583 rows matched
#     Merged game dates: 595/595 rows matched
# Processed 900 files...
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 501/501 rows matched
#     Merged game dates: 514/514 rows matched
#     Merged game dates: 557/557 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 593/593 rows matched
#     Merged game dates: 483/483 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 538/538 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 582/582 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 512/512 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 486/486 rows matched
#     Merged game dates: 459/459 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 477/477 rows matched
#     Merged game dates: 507/507 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 564/564 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 582/582 rows matched
#     Merged game dates: 476/476 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 562/562 rows matched
#     Merged game dates: 456/456 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 570/570 rows matched
#     Merged game dates: 492/492 rows matched
#     Merged game dates: 509/509 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 579/579 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 580/580 rows matched
#     Merged game dates: 581/581 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 490/490 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 618/618 rows matched
#     Merged game dates: 502/502 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 549/549 rows matched
#     Merged game dates: 508/508 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 566/566 rows matched
#     Merged game dates: 530/530 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 604/604 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 522/522 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 553/553 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 591/591 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 531/531 rows matched
#     Merged game dates: 579/579 rows matched
#     Merged game dates: 528/528 rows matched
#     Merged game dates: 552/552 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 482/482 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 492/492 rows matched
#     Merged game dates: 515/515 rows matched
#     Merged game dates: 501/501 rows matched
#     Merged game dates: 574/574 rows matched
# Processed 1000 files...
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 499/499 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 529/529 rows matched
#     Merged game dates: 556/556 rows matched
#     Merged game dates: 578/578 rows matched
#     Merged game dates: 577/577 rows matched
#     Merged game dates: 560/560 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 505/505 rows matched
#     Merged game dates: 598/598 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 506/506 rows matched
#     Merged game dates: 525/525 rows matched
#     Merged game dates: 486/486 rows matched
#     Merged game dates: 626/626 rows matched
#     Merged game dates: 517/517 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 563/563 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 533/533 rows matched
#     Merged game dates: 510/510 rows matched
#     Merged game dates: 544/544 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 460/460 rows matched
#     Merged game dates: 547/547 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 532/532 rows matched
#     Merged game dates: 535/535 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 576/576 rows matched
#     Merged game dates: 497/497 rows matched
#     Merged game dates: 540/540 rows matched
#     Merged game dates: 521/521 rows matched
#     Merged game dates: 518/518 rows matched
#     Merged game dates: 499/499 rows matched
#     Merged game dates: 590/590 rows matched
#     Merged game dates: 516/516 rows matched
#     Merged game dates: 491/491 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 561/561 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 523/523 rows matched
#     Merged game dates: 550/550 rows matched
#     Merged game dates: 568/568 rows matched
#     Merged game dates: 551/551 rows matched
#     Merged game dates: 477/477 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 577/577 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 637/637 rows matched
#     Merged game dates: 507/507 rows matched
#     Merged game dates: 524/524 rows matched
#     Merged game dates: 520/520 rows matched
#     Merged game dates: 554/554 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 559/559 rows matched
#     Merged game dates: 618/618 rows matched
#     Merged game dates: 492/492 rows matched
#     Merged game dates: 527/527 rows matched
#     Merged game dates: 571/571 rows matched
#     Merged game dates: 543/543 rows matched
#     Merged game dates: 548/548 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 511/511 rows matched
#     Merged game dates: 504/504 rows matched
#     Merged game dates: 545/545 rows matched
#     Merged game dates: 558/558 rows matched
#     Merged game dates: 536/536 rows matched
#     Merged game dates: 555/555 rows matched
#     Merged game dates: 534/534 rows matched
#     Merged game dates: 539/539 rows matched
#     Merged game dates: 498/498 rows matched
#     Merged game dates: 541/541 rows matched
#     Merged game dates: 519/519 rows matched
#     Merged game dates: 573/573 rows matched
#     Merged game dates: 545/545 rows matched
# ...
# Created: organized_data/playoffs/DAL_2024_ps.csv (11877 rows, 22 games, 22 games with dates)
# Created: organized_data/regular_season/DAL_2023_rs.csv (43428 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/DAL_2025_rs.csv (45321 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/DAL_2022_rs.csv (43111 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/DAL_2022_ps.csv (9207 rows, 18 games, 18 games with dates)
# Created: organized_data/regular_season/DAL_2021_rs.csv (38154 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/DAL_2021_ps.csv (3577 rows, 7 games, 7 games with dates)
# Created: organized_data/regular_season/BOS_2024_rs.csv (42291 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/BOS_2024_ps.csv (9374 rows, 19 games, 19 games with dates)
# Created: organized_data/regular_season/BOS_2022_rs.csv (43305 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/BOS_2022_ps.csv (12788 rows, 24 games, 24 games with dates)
# Created: organized_data/regular_season/BOS_2025_rs.csv (42516 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/BOS_2025_ps.csv (5701 rows, 11 games, 11 games with dates)
# Created: organized_data/regular_season/BOS_2023_rs.csv (43128 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/BOS_2023_ps.csv (10068 rows, 20 games, 20 games with dates)
# Created: organized_data/regular_season/BOS_2021_rs.csv (38745 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/BOS_2021_ps.csv (2723 rows, 5 games, 5 games with dates)
# Created: organized_data/regular_season/PHX_2023_rs.csv (44240 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/PHX_2023_ps.csv (5762 rows, 11 games, 11 games with dates)
# Created: organized_data/regular_season/PHX_2022_rs.csv (43871 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/PHX_2022_ps.csv (6703 rows, 13 games, 13 games with dates)
# Created: organized_data/regular_season/PHX_2021_rs.csv (37345 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/PHX_2021_ps.csv (11368 rows, 22 games, 22 games with dates)
# Created: organized_data/regular_season/PHX_2025_rs.csv (44184 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/PHX_2024_rs.csv (44297 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/PHX_2024_ps.csv (2204 rows, 4 games, 4 games with dates)
# Created: organized_data/regular_season/POR_2025_rs.csv (45143 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/POR_2023_rs.csv (43507 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/POR_2022_rs.csv (43582 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/POR_2024_rs.csv (43680 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/POR_2021_rs.csv (37930 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/POR_2021_ps.csv (3235 rows, 6 games, 6 games with dates)
# Created: organized_data/regular_season/MIN_2025_rs.csv (44202 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/MIN_2025_ps.csv (8191 rows, 15 games, 15 games with dates)
# Created: organized_data/regular_season/MIN_2021_rs.csv (39691 rows, 72 games, 72 games with dates)
# Created: organized_data/regular_season/MIN_2023_rs.csv (45315 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/MIN_2023_ps.csv (2621 rows, 5 games, 5 games with dates)
# Created: organized_data/regular_season/MIN_2022_rs.csv (45569 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/MIN_2022_ps.csv (3553 rows, 6 games, 6 games with dates)
# Created: organized_data/regular_season/MIN_2024_rs.csv (44169 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/MIN_2024_ps.csv (8362 rows, 16 games, 16 games with dates)
# Created: organized_data/regular_season/MEM_2022_rs.csv (46238 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/MEM_2022_ps.csv (6939 rows, 12 games, 12 games with dates)
# Created: organized_data/playoffs/MEM_2023_ps.csv (3376 rows, 6 games, 6 games with dates)
# Created: organized_data/regular_season/MEM_2023_rs.csv (45734 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/MEM_2025_rs.csv (48396 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/MEM_2025_ps.csv (2317 rows, 4 games, 4 games with dates)
# Created: organized_data/regular_season/MEM_2021_rs.csv (39536 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/MEM_2021_ps.csv (2670 rows, 5 games, 5 games with dates)
# Created: organized_data/regular_season/MEM_2024_rs.csv (44473 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/DEN_2025_rs.csv (44295 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/DEN_2025_ps.csv (7690 rows, 14 games, 14 games with dates)
# Created: organized_data/regular_season/DEN_2022_rs.csv (42935 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/DEN_2022_ps.csv (2768 rows, 5 games, 5 games with dates)
# Created: organized_data/regular_season/DEN_2024_rs.csv (43123 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/DEN_2024_ps.csv (5990 rows, 12 games, 12 games with dates)
# Created: organized_data/regular_season/DEN_2023_rs.csv (42988 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/DEN_2023_ps.csv (10137 rows, 20 games, 20 games with dates)
# Created: organized_data/regular_season/DEN_2021_rs.csv (37562 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/DEN_2021_ps.csv (5286 rows, 10 games, 10 games with dates)
# Created: organized_data/regular_season/CHI_2025_rs.csv (45125 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CHI_2024_rs.csv (43937 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CHI_2023_rs.csv (43180 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CHI_2022_rs.csv (43076 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/CHI_2022_ps.csv (2740 rows, 5 games, 5 games with dates)
# Created: organized_data/regular_season/CHI_2021_rs.csv (38070 rows, 72 games, 72 games with dates)
# Created: organized_data/regular_season/CHA_2022_rs.csv (44728 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CHA_2024_rs.csv (42436 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CHA_2023_rs.csv (45156 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CHA_2021_rs.csv (39075 rows, 72 games, 72 games with dates)
# Created: organized_data/regular_season/CHA_2025_rs.csv (45226 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/HOU_2022_rs.csv (44786 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/HOU_2023_rs.csv (45178 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/HOU_2024_rs.csv (45511 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/HOU_2021_rs.csv (38221 rows, 72 games, 72 games with dates)
# Created: organized_data/regular_season/HOU_2025_rs.csv (45810 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/HOU_2025_ps.csv (3972 rows, 7 games, 7 games with dates)
# Created: organized_data/regular_season/PHI_2022_rs.csv (42966 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/PHI_2022_ps.csv (6080 rows, 12 games, 12 games with dates)
# Created: organized_data/regular_season/PHI_2024_rs.csv (44144 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/PHI_2024_ps.csv (3043 rows, 6 games, 6 games with dates)
# Created: organized_data/regular_season/PHI_2025_rs.csv (43850 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/PHI_2023_rs.csv (43020 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/PHI_2023_ps.csv (5535 rows, 11 games, 11 games with dates)
# Created: organized_data/regular_season/PHI_2021_rs.csv (38904 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/PHI_2021_ps.csv (6727 rows, 12 games, 12 games with dates)
# Created: organized_data/regular_season/UTA_2021_rs.csv (38540 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/UTA_2021_ps.csv (5761 rows, 11 games, 11 games with dates)
# Created: organized_data/regular_season/UTA_2025_rs.csv (44877 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/UTA_2023_rs.csv (45032 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/UTA_2024_rs.csv (44021 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/UTA_2022_rs.csv (43773 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/UTA_2022_ps.csv (3090 rows, 6 games, 6 games with dates)
# Created: organized_data/regular_season/CLE_2024_rs.csv (43838 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/CLE_2024_ps.csv (6057 rows, 12 games, 12 games with dates)
# Created: organized_data/regular_season/CLE_2022_rs.csv (43391 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/CLE_2025_rs.csv (44855 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/CLE_2025_ps.csv (4911 rows, 9 games, 9 games with dates)
# Created: organized_data/regular_season/CLE_2021_rs.csv (38254 rows, 72 games, 72 games with dates)
# Created: organized_data/regular_season/CLE_2023_rs.csv (43073 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/CLE_2023_ps.csv (2545 rows, 5 games, 5 games with dates)
# Created: organized_data/playoffs/NYK_2025_ps.csv (9964 rows, 18 games, 18 games with dates)
# Created: organized_data/regular_season/NYK_2025_rs.csv (42540 rows, 82 games, 82 games with dates)
# Created: organized_data/regular_season/NYK_2024_rs.csv (42153 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/NYK_2024_ps.csv (6561 rows, 13 games, 13 games with dates)
# Created: organized_data/regular_season/NYK_2021_rs.csv (37401 rows, 72 games, 72 games with dates)
# Created: organized_data/playoffs/NYK_2021_ps.csv (2552 rows, 5 games, 5 games with dates)
# Created: organized_data/regular_season/NYK_2023_rs.csv (43593 rows, 82 games, 82 games with dates)
# Created: organized_data/playoffs/NYK_2023_ps.csv (5627 rows, 11 games, 11 games with dates)
# Created: organized_data/regular_season/NYK_2022_rs.csv (43224 rows, 82 games, 82 games with dates)
#
# Data organization complete!
# Total files created: 230
#
# Summary by team:
#   ATL: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(18)', '2022(5)', '2023(6)']
#   BKN: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(12)', '2022(4)', '2023(4)']
#   BOS: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(5)', '2022(24)', '2023(20)', '2024(19)', '2025(11)']
#   CHA: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: []
#   CHI: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2022(5)']
#   CLE: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2023(5)', '2024(12)', '2025(9)']
#   DAL: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(7)', '2022(18)', '2024(22)']
#   DEN: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(10)', '2022(5)', '2023(20)', '2024(12)', '2025(14)']
#   DET: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2025(6)']
#   GSW: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2022(22)', '2023(13)', '2025(12)']
#   HOU: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2025(7)']
#   IND: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2024(17)', '2025(23)']
#   LAC: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(19)', '2023(5)', '2024(6)', '2025(7)']
#   LAL: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(6)', '2023(16)', '2024(5)', '2025(5)']
#   MEM: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(5)', '2022(12)', '2023(6)', '2025(4)']
#   MIA: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(4)', '2022(18)', '2023(23)', '2024(5)', '2025(4)']
#   MIL: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(23)', '2022(12)', '2023(5)', '2024(6)', '2025(5)']
#   MIN: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2022(6)', '2023(5)', '2024(16)', '2025(15)']
#   NOP: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2022(6)', '2024(4)']
#   NYK: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(5)', '2023(11)', '2024(13)', '2025(18)']
#   OKC: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2024(10)', '2025(23)']
#   ORL: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2024(7)', '2025(5)']
#   PHI: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(12)', '2022(12)', '2023(11)', '2024(6)']
#   PHX: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(22)', '2022(13)', '2023(11)', '2024(4)']
#   POR: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(6)']
#   SAC: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2023(7)']
#   SAS: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: []
#   TOR: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2022(6)']
#   UTA: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(11)', '2022(6)']
#   WAS: RS: ['2021(72)', '2022(82)', '2023(82)', '2024(82)', '2025(82)'], PS: ['2021(5)']
#
# Verifying organized data files...
# Regular season files: 150
# Playoff files: 80
#   MEM_2022_rs.csv: 46238 rows, 82 games, teams: ['CLE', 'MEM', 'LAC', 'LAL', 'POR', 'GSW', 'MIA', 'DEN', 'WAS', 'MIN', 'CHA', 'PHX', 'NOP', 'HOU', 'UTA', 'TOR', 'ATL', 'SAC', 'OKC', 'DAL', 'PHI', 'SAS', 'BKN', 'DET', 'CHI', 'MIL', 'NYK', 'ORL', 'BOS', 'IND']
#     New columns - date: True(46238), playoffs: True, team: True, opp_team: True
#     Sample: date=20211020, team=CLE, opp_team=MEM
#   WAS_2021_rs.csv: 40240 rows, 72 games, teams: ['PHI', 'WAS', 'ORL', 'CHI', 'MIN', 'BKN', 'BOS', 'MIA', 'PHX', 'SAS', 'HOU', 'NOP', 'ATL', 'POR', 'CHA', 'TOR', 'NYK', 'DEN', 'LAL', 'LAC', 'MEM', 'MIL', 'SAC', 'UTA', 'DET', 'IND', 'DAL', 'GSW', 'OKC', 'CLE']
#     New columns - date: True(40240), playoffs: True, team: True, opp_team: True
#     Sample: date=20201223, team=PHI, opp_team=WAS
#   PHX_2025_rs.csv: 44184 rows, 82 games, teams: ['LAC', 'PHX', 'LAL', 'DAL', 'POR', 'PHI', 'MIA', 'SAC', 'UTA', 'OKC', 'MIN', 'ORL', 'NYK', 'BKN', 'GSW', 'SAS', 'NOP', 'IND', 'DET', 'DEN', 'MEM', 'CHA', 'ATL', 'WAS', 'CLE', 'HOU', 'CHI', 'TOR', 'MIL', 'BOS']
#     New columns - date: True(44184), playoffs: True, team: True, opp_team: True
#     Sample: date=20241023, team=LAC, opp_team=PHX
#   BKN_2024_rs.csv: 44126 rows, 82 games, teams: ['BKN', 'CLE', 'DAL', 'CHA', 'MIA', 'CHI', 'BOS', 'MIL', 'LAC', 'WAS', 'ORL', 'PHI', 'ATL', 'TOR', 'SAC', 'PHX', 'DEN', 'GSW', 'UTA', 'NYK', 'DET', 'OKC', 'NOP', 'HOU', 'POR', 'LAL', 'MIN', 'SAS', 'MEM', 'IND']
#     New columns - date: True(44126), playoffs: True, team: True, opp_team: True
#     Sample: date=20231025, team=BKN, opp_team=CLE
#   CHI_2024_rs.csv: 43937 rows, 82 games, teams: ['OKC', 'CHI', 'TOR', 'DET', 'IND', 'DAL', 'BKN', 'DEN', 'UTA', 'PHX', 'MIL', 'ORL', 'MIA', 'BOS', 'NOP', 'CHA', 'SAS', 'PHI', 'LAL', 'CLE', 'ATL', 'NYK', 'HOU', 'GSW', 'MEM', 'POR', 'SAC', 'MIN', 'LAC', 'WAS']
#     New columns - date: True(43937), playoffs: True, team: True, opp_team: True
#     Sample: date=20231025, team=OKC, opp_team=CHI
#
# Process complete!
