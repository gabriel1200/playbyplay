# %%
import pandas as pd
import os
import glob
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

def get_team_acronym_from_id(team_id):
    """Convert team ID to team acronym using the provided dictionary"""
    team_dict = {
        '1610612760': 'OKC', '1610612749': 'MIL', '1610612758': 'SAC', '1610612747': 'LAL',
        '1610612738': 'BOS', '1610612743': 'DEN', '1610612750': 'MIN', '1610612752': 'NYK',
        '1610612756': 'PHX', '1610612753': 'ORL', '1610612766': 'CHA', '1610612739': 'CLE',
        '1610612746': 'LAC', '1610612737': 'ATL', '1610612748': 'MIA', '1610612742': 'DAL',
        '1610612765': 'DET', '1610612763': 'MEM', '1610612761': 'TOR', '1610612741': 'CHI',
        '1610612754': 'IND', '1610612759': 'SAS', '1610612745': 'HOU', '1610612751': 'BKN',
        '1610612764': 'WAS', '1610612744': 'GSW', '1610612755': 'PHI', '1610612762': 'UTA',
        '1610612757': 'POR', '1610612740': 'NOP'
    }
    
    team_id_str = str(int(team_id)) if pd.notna(team_id) else None
    return team_dict.get(team_id_str, f'UNKNOWN_{team_id_str}')

def determine_game_type(game_id):
    """Determine if game is regular season (rs) or playoffs (ps) based on game ID"""
    game_id_str = str(game_id)
    if game_id_str.startswith('4'):
        return 'ps'  # Playoffs
    elif game_id_str.startswith('2'):
        return 'rs'  # Regular season
    else:
        return 'unknown'

def collect_and_organize_data():
    """Main function to collect and organize scraped PBP data"""
    
    # Create output directories
    os.makedirs('organized_data', exist_ok=True)
    os.makedirs('organized_data/regular_season', exist_ok=True)
    os.makedirs('organized_data/playoffs', exist_ok=True)
    
    # Get all CSV files from pbp_data directory
    pbp_files = glob.glob('pbp_data/*.csv')
    
    if not pbp_files:
        print("No PBP data files found in pbp_data directory!")
        return
    
    print(f"Found {len(pbp_files)} PBP data files")
    
    # Dictionary to store data by team, year, and game type
    team_data = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
    
    # Process each file
    processed_files = 0
    skipped_files = 0
    
    for file_path in pbp_files:
        try:
            # Extract year from filename (format: YYYY_GAMEID.csv)
            filename = os.path.basename(file_path)
            if '_' not in filename:
                print(f"Skipping file with unexpected format: {filename}")
                skipped_files += 1
                continue
            
            year = filename.split('_')[0]
            
            # Read the CSV file
            df = pd.read_csv(file_path)
            
            if df.empty:
                print(f"Skipping empty file: {filename}")
                skipped_files += 1
                continue
            
            # Check if required columns exist
            required_columns = ['teamId', 'game_id']
            missing_columns = [col for col in required_columns if col not in df.columns]
            if missing_columns:
                print(f"Skipping file {filename} - missing columns: {missing_columns}")
                skipped_files += 1
                continue
            
            # Get unique teams and game type for this file
            unique_teams = df['teamId'].dropna().unique()
            
            if len(unique_teams) == 0:
                print(f"No valid team IDs found in {filename}")
                skipped_files += 1
                continue
            
            # Determine game type from game_id
            game_ids = df['game_id'].dropna().unique()
            if len(game_ids) == 0:
                print(f"No valid game IDs found in {filename}")
                skipped_files += 1
                continue
            
            # Use first game_id to determine game type (should be consistent within file)
            game_type = determine_game_type(game_ids[0])
            
            if game_type == 'unknown':
                print(f"Unknown game type for {filename} (game_id: {game_ids[0]})")
                skipped_files += 1
                continue
            
            # Group data by team
            for team_id in unique_teams:
                team_acronym = get_team_acronym_from_id(team_id)
                team_df = df[df['teamId'] == team_id].copy()
                
                if not team_df.empty:
                    team_data[team_acronym][year][game_type].append(team_df)
            
            processed_files += 1
            
            if processed_files % 100 == 0:
                print(f"Processed {processed_files} files...")
                
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
            skipped_files += 1
            continue
    
    print(f"\nProcessed {processed_files} files, skipped {skipped_files} files")
    
    # Combine and save data for each team/year/game_type combination
    total_files_created = 0
    
    for team_acronym in team_data:
        for year in team_data[team_acronym]:
            for game_type in team_data[team_acronym][year]:
                # Combine all DataFrames for this team/year/game_type
                combined_df = pd.concat(team_data[team_acronym][year][game_type], ignore_index=True)
                
                # Sort by game_id and actionNumber for consistent ordering
                combined_df = combined_df.sort_values(['game_id', 'actionNumber'])
                
                # Create filename
                game_type_folder = 'regular_season' if game_type == 'rs' else 'playoffs'
                filename = f"organized_data/{game_type_folder}/{team_acronym}_{year}_{game_type}.csv"
                
                # Save to CSV
                combined_df.to_csv(filename, index=False)
                
                total_files_created += 1
                print(f"Created: {filename} ({len(combined_df)} rows)")
    
    print(f"\nData organization complete!")
    print(f"Total files created: {total_files_created}")
    
    # Print summary statistics
    print("\nSummary by team:")
    for team_acronym in sorted(team_data.keys()):
        years = sorted(team_data[team_acronym].keys())
        rs_years = []
        ps_years = []
        
        for year in years:
            if 'rs' in team_data[team_acronym][year]:
                rs_years.append(year)
            if 'ps' in team_data[team_acronym][year]:
                ps_years.append(year)
        
        print(f"  {team_acronym}: RS years: {rs_years}, PS years: {ps_years}")

def verify_organized_data():
    """Verify the organized data files"""
    print("\nVerifying organized data files...")
    
    rs_files = glob.glob('organized_data/regular_season/*.csv')
    ps_files = glob.glob('organized_data/playoffs/*.csv')
    
    print(f"Regular season files: {len(rs_files)}")
    print(f"Playoff files: {len(ps_files)}")
    
    # Sample a few files to verify structure
    sample_files = (rs_files + ps_files)[:5]
    
    for file_path in sample_files:
        try:
            df = pd.read_csv(file_path)
            filename = os.path.basename(file_path)
            print(f"  {filename}: {len(df)} rows, {len(df.columns)} columns")
            
            # Check game type consistency
            game_ids = df['game_id'].unique()
            game_types = [determine_game_type(gid) for gid in game_ids]
            unique_game_types = set(game_types)
            
            if len(unique_game_types) > 1:
                print(f"    WARNING: Mixed game types found: {unique_game_types}")
            
        except Exception as e:
            print(f"    ERROR reading {file_path}: {e}")

if __name__ == "__main__":
    print("Starting NBA PBP data collection and organization...")
    collect_and_organize_data()
    verify_organized_data()
    print("\nProcess complete!")
# Out:
# Starting NBA PBP data collection and organization...
# Found 6422 PBP data files
# Processed 100 files...
# Processed 200 files...
# Processed 300 files...
# Processed 400 files...
# Processed 500 files...
# Processed 600 files...
# Processed 700 files...
# Processed 800 files...
# Processed 900 files...
# Processed 1000 files...
# Processed 1100 files...
# Processed 1200 files...
# Processed 1300 files...
# Processed 1400 files...
# Processed 1500 files...
# Processed 1600 files...
# Processed 1700 files...
# Processed 1800 files...
# Processed 1900 files...
# Processed 2000 files...
# Processed 2100 files...
# Processed 2200 files...
# Processed 2300 files...
# Processed 2400 files...
# Processed 2500 files...
# Processed 2600 files...
# Processed 2700 files...
# Processed 2800 files...
# Processed 2900 files...
# Processed 3000 files...
# Processed 3100 files...
# Processed 3200 files...
# Processed 3300 files...
# Processed 3400 files...
# Processed 3500 files...
# Processed 3600 files...
# Processed 3700 files...
# Processed 3800 files...
# Processed 3900 files...
# Processed 4000 files...
# Processed 4100 files...
# Processed 4200 files...
# Processed 4300 files...
# Processed 4400 files...
# Processed 4500 files...
# Processed 4600 files...
# Processed 4700 files...
# Processed 4800 files...
# Processed 4900 files...
# Processed 5000 files...
# Processed 5100 files...
# Processed 5200 files...
# Processed 5300 files...
# Processed 5400 files...
# Processed 5500 files...
# Processed 5600 files...
# Processed 5700 files...
# Processed 5800 files...
# Processed 5900 files...
# Processed 6000 files...
# Processed 6100 files...
# Processed 6200 files...
# Processed 6300 files...
# Processed 6400 files...
#
# Processed 6422 files, skipped 0 files
# Created: organized_data/regular_season/SAC_2021_rs.csv (19091 rows)
# Created: organized_data/regular_season/SAC_2025_rs.csv (22083 rows)
# Created: organized_data/regular_season/SAC_2024_rs.csv (22558 rows)
# Created: organized_data/regular_season/SAC_2022_rs.csv (21953 rows)
# Created: organized_data/regular_season/SAC_2023_rs.csv (22619 rows)
# Created: organized_data/playoffs/SAC_2023_ps.csv (2129 rows)
# Created: organized_data/regular_season/ORL_2021_rs.csv (19031 rows)
# Created: organized_data/regular_season/ORL_2025_rs.csv (21928 rows)
# Created: organized_data/playoffs/ORL_2025_ps.csv (1281 rows)
# Created: organized_data/regular_season/ORL_2023_rs.csv (21548 rows)
# Created: organized_data/regular_season/ORL_2022_rs.csv (21249 rows)
# Created: organized_data/regular_season/ORL_2024_rs.csv (21619 rows)
# Created: organized_data/playoffs/ORL_2024_ps.csv (1857 rows)
# Created: organized_data/regular_season/SAS_2023_rs.csv (23326 rows)
# Created: organized_data/regular_season/SAS_2021_rs.csv (19274 rows)
# Created: organized_data/regular_season/SAS_2025_rs.csv (22389 rows)
# Created: organized_data/regular_season/SAS_2024_rs.csv (22593 rows)
# Created: organized_data/regular_season/SAS_2022_rs.csv (23013 rows)
# Created: organized_data/regular_season/OKC_2023_rs.csv (23460 rows)
# Created: organized_data/regular_season/OKC_2024_rs.csv (23193 rows)
# Created: organized_data/playoffs/OKC_2024_ps.csv (2745 rows)
# Created: organized_data/regular_season/OKC_2022_rs.csv (21911 rows)
# Created: organized_data/regular_season/OKC_2025_rs.csv (22834 rows)
# Created: organized_data/playoffs/OKC_2025_ps.csv (6866 rows)
# Created: organized_data/regular_season/OKC_2021_rs.csv (18974 rows)
# Created: organized_data/regular_season/ATL_2023_rs.csv (22084 rows)
# Created: organized_data/playoffs/ATL_2023_ps.csv (1535 rows)
# Created: organized_data/regular_season/ATL_2024_rs.csv (22194 rows)
# Created: organized_data/playoffs/LAL_2024_ps.csv (1218 rows)
# Created: organized_data/regular_season/LAL_2025_rs.csv (21841 rows)
# Created: organized_data/playoffs/LAL_2025_ps.csv (1257 rows)
# Created: organized_data/regular_season/DAL_2024_rs.csv (22407 rows)
# Created: organized_data/playoffs/DAL_2024_ps.csv (6113 rows)
# Created: organized_data/regular_season/DAL_2023_rs.csv (21199 rows)
# Created: organized_data/regular_season/DAL_2025_rs.csv (22880 rows)
# Created: organized_data/regular_season/DAL_2022_rs.csv (21488 rows)
# Created: organized_data/playoffs/DAL_2022_ps.csv (4499 rows)
# Created: organized_data/regular_season/DAL_2021_rs.csv (19162 rows)
# Created: organized_data/playoffs/DAL_2021_ps.csv (1780 rows)
# Created: organized_data/regular_season/BOS_2024_rs.csv (21201 rows)
# Created: organized_data/playoffs/BOS_2024_ps.csv (4684 rows)
# Created: organized_data/regular_season/BOS_2022_rs.csv (21499 rows)
# Created: organized_data/playoffs/BOS_2022_ps.csv (6205 rows)
# Created: organized_data/regular_season/BOS_2025_rs.csv (21028 rows)
# Created: organized_data/playoffs/BOS_2025_ps.csv (2850 rows)
# Created: organized_data/regular_season/BOS_2023_rs.csv (21410 rows)
# Created: organized_data/playoffs/BOS_2023_ps.csv (5081 rows)
# Created: organized_data/regular_season/BOS_2021_rs.csv (19627 rows)
# Created: organized_data/playoffs/BOS_2021_ps.csv (1380 rows)
# Created: organized_data/regular_season/PHX_2023_rs.csv (22184 rows)
# Created: organized_data/playoffs/PHX_2023_ps.csv (2880 rows)
# Created: organized_data/regular_season/PHX_2022_rs.csv (21713 rows)
# Created: organized_data/playoffs/PHX_2022_ps.csv (3280 rows)
# Created: organized_data/regular_season/PHX_2021_rs.csv (18594 rows)
# Created: organized_data/playoffs/PHX_2021_ps.csv (5535 rows)
# Created: organized_data/regular_season/PHX_2025_rs.csv (22041 rows)
# Created: organized_data/regular_season/PHX_2024_rs.csv (22398 rows)
# Created: organized_data/playoffs/PHX_2024_ps.csv (1052 rows)
# Created: organized_data/regular_season/POR_2025_rs.csv (22404 rows)
# Created: organized_data/regular_season/POR_2023_rs.csv (21351 rows)
# Created: organized_data/regular_season/POR_2022_rs.csv (21491 rows)
# Created: organized_data/regular_season/POR_2024_rs.csv (21552 rows)
# Created: organized_data/regular_season/POR_2021_rs.csv (18828 rows)
# Created: organized_data/playoffs/POR_2021_ps.csv (1586 rows)
# Created: organized_data/regular_season/MIN_2025_rs.csv (21919 rows)
# Created: organized_data/playoffs/MIN_2025_ps.csv (4066 rows)
# Created: organized_data/regular_season/MIN_2021_rs.csv (19911 rows)
# Created: organized_data/regular_season/MIN_2023_rs.csv (22452 rows)
# Created: organized_data/playoffs/MIN_2023_ps.csv (1293 rows)
# Created: organized_data/regular_season/MIN_2022_rs.csv (22730 rows)
# Created: organized_data/playoffs/MIN_2022_ps.csv (1731 rows)
# Created: organized_data/regular_season/MIN_2024_rs.csv (22219 rows)
# Created: organized_data/playoffs/MIN_2024_ps.csv (4246 rows)
# Created: organized_data/regular_season/MEM_2022_rs.csv (23931 rows)
# Created: organized_data/playoffs/MEM_2022_ps.csv (3528 rows)
# Created: organized_data/playoffs/MEM_2023_ps.csv (1684 rows)
# Created: organized_data/regular_season/MEM_2023_rs.csv (23265 rows)
# Created: organized_data/regular_season/MEM_2025_rs.csv (25054 rows)
# Created: organized_data/playoffs/MEM_2025_ps.csv (1164 rows)
# Created: organized_data/regular_season/MEM_2021_rs.csv (20176 rows)
# Created: organized_data/playoffs/MEM_2021_ps.csv (1319 rows)
# Created: organized_data/regular_season/MEM_2024_rs.csv (22293 rows)
# Created: organized_data/regular_season/DEN_2025_rs.csv (21976 rows)
# Created: organized_data/playoffs/DEN_2025_ps.csv (3786 rows)
# Created: organized_data/regular_season/DEN_2022_rs.csv (21214 rows)
# Created: organized_data/playoffs/DEN_2022_ps.csv (1371 rows)
# Created: organized_data/regular_season/DEN_2024_rs.csv (21488 rows)
# Created: organized_data/playoffs/DEN_2024_ps.csv (2971 rows)
# Created: organized_data/regular_season/DEN_2023_rs.csv (21225 rows)
# Created: organized_data/playoffs/DEN_2023_ps.csv (5112 rows)
# Created: organized_data/regular_season/DEN_2021_rs.csv (18812 rows)
# Created: organized_data/playoffs/DEN_2021_ps.csv (2688 rows)
# Created: organized_data/regular_season/CHI_2025_rs.csv (22523 rows)
# Created: organized_data/regular_season/CHI_2024_rs.csv (22085 rows)
# Created: organized_data/regular_season/CHI_2023_rs.csv (21500 rows)
# Created: organized_data/regular_season/CHI_2022_rs.csv (21528 rows)
# Created: organized_data/playoffs/CHI_2022_ps.csv (1278 rows)
# Created: organized_data/regular_season/CHI_2021_rs.csv (19196 rows)
# Created: organized_data/regular_season/CHA_2022_rs.csv (22267 rows)
# Created: organized_data/regular_season/CHA_2024_rs.csv (21074 rows)
# Created: organized_data/regular_season/CHA_2023_rs.csv (22586 rows)
# Created: organized_data/regular_season/CHA_2021_rs.csv (19828 rows)
# Created: organized_data/regular_season/CHA_2025_rs.csv (23079 rows)
# Created: organized_data/regular_season/HOU_2022_rs.csv (21798 rows)
# Created: organized_data/regular_season/HOU_2023_rs.csv (22875 rows)
# Created: organized_data/regular_season/HOU_2024_rs.csv (22842 rows)
# Created: organized_data/regular_season/HOU_2021_rs.csv (18638 rows)
# Created: organized_data/regular_season/HOU_2025_rs.csv (23422 rows)
# Created: organized_data/playoffs/HOU_2025_ps.csv (1993 rows)
# Created: organized_data/regular_season/PHI_2022_rs.csv (21383 rows)
# Created: organized_data/playoffs/PHI_2022_ps.csv (3034 rows)
# Created: organized_data/regular_season/PHI_2024_rs.csv (22094 rows)
# Created: organized_data/playoffs/PHI_2024_ps.csv (1539 rows)
# Created: organized_data/regular_season/PHI_2025_rs.csv (21623 rows)
# Created: organized_data/regular_season/PHI_2023_rs.csv (21473 rows)
# Created: organized_data/playoffs/PHI_2023_ps.csv (2830 rows)
# Created: organized_data/regular_season/PHI_2021_rs.csv (19550 rows)
# Created: organized_data/playoffs/PHI_2021_ps.csv (3448 rows)
# Created: organized_data/regular_season/UTA_2021_rs.csv (19653 rows)
# Created: organized_data/playoffs/UTA_2021_ps.csv (2908 rows)
# Created: organized_data/regular_season/UTA_2025_rs.csv (22137 rows)
# Created: organized_data/regular_season/UTA_2023_rs.csv (22359 rows)
# Created: organized_data/regular_season/UTA_2024_rs.csv (21685 rows)
# Created: organized_data/regular_season/UTA_2022_rs.csv (22263 rows)
# Created: organized_data/playoffs/UTA_2022_ps.csv (1594 rows)
# Created: organized_data/regular_season/CLE_2024_rs.csv (22020 rows)
# Created: organized_data/playoffs/CLE_2024_ps.csv (2995 rows)
# Created: organized_data/regular_season/CLE_2022_rs.csv (21818 rows)
# Created: organized_data/regular_season/CLE_2025_rs.csv (22424 rows)
# Created: organized_data/playoffs/CLE_2025_ps.csv (2522 rows)
# Created: organized_data/regular_season/CLE_2021_rs.csv (19187 rows)
# Created: organized_data/regular_season/CLE_2023_rs.csv (21501 rows)
# Created: organized_data/playoffs/CLE_2023_ps.csv (1223 rows)
# Created: organized_data/playoffs/NYK_2025_ps.csv (4864 rows)
# Created: organized_data/regular_season/NYK_2025_rs.csv (20829 rows)
# Created: organized_data/regular_season/NYK_2024_rs.csv (20808 rows)
# Created: organized_data/playoffs/NYK_2024_ps.csv (3213 rows)
# Created: organized_data/regular_season/NYK_2021_rs.csv (18387 rows)
# Created: organized_data/playoffs/NYK_2021_ps.csv (1272 rows)
# Created: organized_data/regular_season/NYK_2023_rs.csv (21695 rows)
# Created: organized_data/playoffs/NYK_2023_ps.csv (2841 rows)
# Created: organized_data/regular_season/NYK_2022_rs.csv (21428 rows)
#
# Data organization complete!
# Total files created: 230
#
# Summary by team:
#   ATL: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023']
#   BKN: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023']
#   BOS: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2024', '2025']
#   CHA: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: []
#   CHI: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2022']
#   CLE: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2023', '2024', '2025']
#   DAL: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2024']
#   DEN: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2024', '2025']
#   DET: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2025']
#   GSW: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2022', '2023', '2025']
#   HOU: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2025']
#   IND: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2024', '2025']
#   LAC: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2023', '2024', '2025']
#   LAL: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2023', '2024', '2025']
#   MEM: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2025']
#   MIA: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2024', '2025']
#   MIL: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2024', '2025']
#   MIN: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2022', '2023', '2024', '2025']
#   NOP: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2022', '2024']
#   NYK: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2023', '2024', '2025']
#   OKC: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2024', '2025']
#   ORL: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2024', '2025']
#   PHI: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2024']
#   PHX: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022', '2023', '2024']
#   POR: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021']
#   SAC: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2023']
#   SAS: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: []
#   TOR: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2022']
#   UTA: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021', '2022']
#   WAS: RS years: ['2021', '2022', '2023', '2024', '2025'], PS years: ['2021']
#
# Verifying organized data files...
# Regular season files: 150
# Playoff files: 80
#   MEM_2022_rs.csv: 23931 rows, 25 columns
#   WAS_2021_rs.csv: 19880 rows, 25 columns
#   PHX_2025_rs.csv: 22041 rows, 25 columns
#   BKN_2024_rs.csv: 22385 rows, 25 columns
#   CHI_2024_rs.csv: 22085 rows, 25 columns
#
# Process complete!
